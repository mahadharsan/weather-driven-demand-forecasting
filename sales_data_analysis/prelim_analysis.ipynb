# %%
import pandas as pd
sales = pd.read_csv('D:\\Personal projects\\climate_data_eng\\data\\raw\\m5\\sales_train_evaluation.csv')
cal = pd.read_csv('D:\\Personal projects\\climate_data_eng\\data\\raw\\m5\\calendar.csv')
print('Sales columns first 10:', sales.columns[:10].tolist())
print('Sales shape:', sales.shape)
print('Calendar first row:', cal.iloc[0])
print('Calendar shape:', cal.shape)
# Out:
# Sales columns first 10: ['item_id', 'dept_id', 'cat_id', 'store_id', 'state_id', 'd_1', 'd_2', 'd_3', 'd_4', 'd_5']
# Sales shape: (30490, 1946)
# Calendar first row: date            2011-01-29
# wm_yr_wk             11101
# weekday           Saturday
# wday                     1
# month                    1
# year                  2011
# event_name_1           NaN
# event_type_1           NaN
# event_name_2           NaN
# event_type_2           NaN
# snap_CA                  0
# snap_TX                  0
# snap_WI                  0
# Name: 0, dtype: object
# Calendar shape: (1969, 13)

# %%
import pandas as pd
cal = pd.read_csv('D:\\Personal projects\\climate_data_eng\\data\\raw\\m5\\calendar.csv')
cal['d'] = ['d_' + str(i+1) for i in range(len(cal))]
print(cal[['date', 'd']].head(5))
print(cal[['date', 'd']].tail(5))
# Out:
#          date    d
# 0  2011-01-29  d_1
# 1  2011-01-30  d_2
# 2  2011-01-31  d_3
# 3  2011-02-01  d_4
# 4  2011-02-02  d_5
#             date       d
# 1964  2016-06-15  d_1965
# 1965  2016-06-16  d_1966
# 1966  2016-06-17  d_1967
# 1967  2016-06-18  d_1968
# 1968  2016-06-19  d_1969
